# %% [markdown]
# ## Prisoners: presence of prisoners compared to capacity per region

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from time import sleep
import calendar
import locale
from random import randint

# %% [markdown]
# ### 1. Presence v Capacity
# Extracting monthly data regarding the presence of prisoners in the Italian penitentiary system on regional basis. Data is published on a monthly basis by the Italian Ministry of Justice.

# %%
urls = pd.read_csv('../data/urls.csv')
links = urls.iloc[:, 1].tolist()

# Set locale to Italian to get month names
locale.setlocale(locale.LC_TIME, 'it_IT')
italian_to_english_months = {month: calendar.month_name[i] for i, month in enumerate(calendar.month_name[1:], 1)}

data = []

for link in links:

    html = requests.get(link).text
    soup = BeautifulSoup(html, 'html.parser')
    date_element = soup.find('p', class_='date').text

    for italian, english in italian_to_english_months.items():
        date_element = date_element.replace(italian, english)

    date = pd.to_datetime(date_element, format='%d %B %Y', exact=False, errors='coerce')

    if pd.isnull(date):
        dated = "Unknown"
    else:
        date.strftime('%Y-%m-%d')

    table = soup.find('table')
    rows = table.find_all('tr')[2:]

    for row in rows:
        cols = row.find_all(['th', 'td'])
        regione = cols[0].text.strip()

        if not "totale" in regione.lower():
            capienza_regolamentare = cols[2].text.strip()
            detenuti_presenti = cols[3].text.strip()
            data.append([regione, capienza_regolamentare, detenuti_presenti, date])

    print(f"Fetched data about {link}, {date}")
    print("########")
    sleep(randint(1,3))

df = pd.DataFrame(data, columns=['Region', 'Capacity', 'Present', 'Date'])
# Out:
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST94315, 2018-01-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST99008, 2018-02-28 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST107117, 2018-03-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST156266, 2018-04-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST119037, 2018-05-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST125872, 2018-06-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST131301, 2018-07-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST135462, 2018-08-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST141596, 2018-09-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST155989, 2018-10-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST149070, 2018-11-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST163530, 2018-12-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST168910, 2019-01-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST173662, 2019-02-28 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST183060, 2019-03-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST188292, 2019-04-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST193636, 2019-05-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST206255, 2019-06-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST199192, 2019-07-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST212433, 2019-08-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST219327, 2019-09-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST225648, 2019-10-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST231289, 2019-11-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST238877, 2019-12-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST245309, 2020-01-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST250530, 2020-02-29 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST264737, 2020-03-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST271278, 2020-04-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST276680, 2020-05-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST281517, 2020-06-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST285889, 2020-07-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST289733, 2020-08-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST293959, 2020-09-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST301096, 2020-10-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST308212, 2020-11-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST314822, 2020-12-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST320013, 2021-01-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST323230, 2021-02-28 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST327707, 2021-03-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST331079, 2021-04-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST334398, 2021-05-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST338688, 2021-06-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST342760, 2021-07-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST345746, 2021-08-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST348583, 2021-09-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST352730, 2021-10-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST357663&previsiousPage=mg_1_14, 2021-11-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?facetNode_1=0_2&facetNode_2=0_2_10&facetNode_3=1_5_44&contentId=SST360929&previsiousPage=mg_1_14, 2021-12-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST365654, 2022-01-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST369452, 2022-02-28 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST374273, 2022-03-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST378226, 2022-04-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST382370, 2022-05-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST386405, 2022-06-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST390152, 2022-07-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST393945, 2022-08-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST398010, 2022-09-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST401332, 2022-10-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST405707, 2022-11-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST410260&previsiousPage=mg_1_14, 2022-12-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST414661&previsiousPage=mg_1_14, 2023-01-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST418758, 2023-02-28 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST423473, 2023-03-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST426348, 2023-04-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST431144, 2023-05-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST436103, 2023-06-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST439077, 2023-07-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST442882, 2023-08-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST446494, 2023-09-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST447997, 2023-10-31 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST454080, 2023-11-30 00:00:00
# ########
# Fetched data about https://www.giustizia.it/giustizia/it/mg_1_14_1.page?contentId=SST449575, 2023-12-31 00:00:00
# ########

# %%
df.sample(10)
# Out:
#                      Region Capacity Present       Date
# 234                 SICILIA    6.497   6.469 2018-12-31
# 1358          VALLE D'AOSTA      181     114 2023-08-31
# 1044         EMILIA ROMAGNA    2.998   3.291 2022-05-31
# 127                 LIGURIA    1.129   1.455 2018-07-31
# 591                PIEMONTE    3.938   4.176 2020-06-30
# 405   FRIULI VENEZIA GIULIA      479     666 2019-09-30
# 305   FRIULI VENEZIA GIULIA      480     641 2019-04-30
# 360                 ABRUZZO    1.645   2.077 2019-07-31
# 524          EMILIA ROMAGNA    3.002   3.261 2020-03-31
# 205   FRIULI VENEZIA GIULIA      480     630 2018-11-30

# %%
df.to_csv('../outputs/capacityvpresence.csv', index=False)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df.to_csv('../outputs/capacityvpresence.csv', index=False)
#
# NameError: name 'df' is not defined
